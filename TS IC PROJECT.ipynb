# %%
##    TS IC PROJECT

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_excel('NFHS.xlsx')

# %%
df.head(5)
# Out:
#    Sl.No                          Category  \
# 0    1.0  Population and Household Profile
# 1    2.0  Population and Household Profile
# 2    3.0  Population and Household Profile
# 3    4.0  Population and Household Profile
# 4    5.0  Population and Household Profile
#
#                                 Indicators (2019-20) Urban Rural  \
# 0  1. Female population age 6 years and above who...  75.9  52.4
# 1               2. Population below age 15 years (%)  23.4    22
# 2  3. Sex ratio of the total population (females ...  1015  1070
# 3  4. Sex ratio at birth for children born in the...   873   907
# 4  5. Children under age 5 years whose birth was ...  92.9    88
#
#   Total (2019-20) Total (2015-16) Adilabad Bhadradri Hyderabad  ...  \
# 0            60.9            62.6     58.6      62.7      80.3  ...
# 1            22.5            25.1     24.8      19.5        23  ...
# 2            1049            1007      992      1082       959  ...
# 3             894             872      785       817       844  ...
# 4              90            83.1     83.9        90      94.3  ...
#
#   Rajanna Sircilla Ranga Reddy Sangareddy Siddipet Suryapet Vikarabad  \
# 0             56.4        68.6       60.2     60.8     57.4      53.1
# 1             21.3        24.1       24.5       22     18.9      24.9
# 2             1167        1022       1053     1062     1032       998
# 3             1115         964       1039      976      980       775
# 4             91.2        93.4       79.7       90     92.7      91.6
#
#   Wanaparthy, Warangal Rural Warangal Urban Yadadri
# 0        49.3           51.8           70.3    59.1
# 1        24.8           17.3           20.2      23
# 2        1018           1070           1087    1071
# 3         987            698            829     954
# 4        90.5           82.6           82.4    93.8
#
# [5 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['Sl.No', 'Category', 'Indicators (2019-20)', 'Urban', 'Rural',
#        'Total (2019-20)', 'Total (2015-16)', 'Adilabad', 'Bhadradri',
#        'Hyderabad', 'Jagitial', 'Jangoan', 'Jayashankar Bhupalapally',
#        'Jogulamba Gadwal', 'Kamareddy', 'Karimnagar', 'Khammam',
#        'KumurumBheem', 'Mahabubabad', 'Mahabubnagar', 'Mancherial', 'Medak',
#        'Medchal-Malkajgiri', 'Nagarkurnool', 'Nalgonda', 'Nirmal', 'Nizamabad',
#        'Peddapalli', 'Rajanna Sircilla', 'Ranga Reddy', 'Sangareddy',
#        'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy,', 'Warangal Rural',
#        'Warangal Urban', 'Yadadri'],
#       dtype='object')

# %%
list(df['Category'])
# Out:
# ['Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Population and Household Profile',
#  'Characteristics of Women (age 15-49 years)',
#  'Characteristics of Women (age 15-49 years)',
#  'Marriage and Fertility',
#  'Marriage and Fertility',
#  'Marriage and Fertility',
#  'Marriage and Fertility',
#  'Current Use of Family Planning Methods (currently married women age 15–49 years)',
#  'Current Use of Family Planning Methods (currently married women age 15–49 years)',
#  'Current Use of Family Planning Methods (currently married women age 15–49 years)',
#  'Current Use of Family Planning Methods (currently married women age 15–49 years)',
#  'Current Use of Family Planning Methods (currently married women age 15–49 years)',
#  'Current Use of Family Planning Methods (currently married women age 15–49 years)',
#  'Current Use of Family Planning Methods (currently married women age 15–49 years)',
#  'Current Use of Family Planning Methods (currently married women age 15–49 years)',
#  'Unmet Need for Family Planning (currently married women age 15–49 years)',
#  'Unmet Need for Family Planning (currently married women age 15–49 years)',
#  'Quality of Family Planning Services',
#  'Quality of Family Planning Services',
#  'Maternal and Child Health Maternity Care (for last birth in the 5 years before the survey)',
#  'Maternal and Child Health Maternity Care (for last birth in the 5 years before the survey)',
#  'Maternal and Child Health Maternity Care (for last birth in the 5 years before the survey)',
#  'Maternal and Child Health Maternity Care (for last birth in the 5 years before the survey)',
#  'Maternal and Child Health Maternity Care (for last birth in the 5 years before the survey)',
#  'Maternal and Child Health Maternity Care (for last birth in the 5 years before the survey)',
#  'Maternal and Child Health Maternity Care (for last birth in the 5 years before the survey)',
#  'Maternal and Child Health Maternity Care (for last birth in the 5 years before the survey)',
#  'Maternal and Child Health Maternity Care (for last birth in the 5 years before the survey)',
#  'Maternal and Child Health Maternity Care (for last birth in the 5 years before the survey)',
#  'Delivery Care (for births in the 5 years before the survey)',
#  'Delivery Care (for births in the 5 years before the survey)',
#  'Delivery Care (for births in the 5 years before the survey)',
#  'Delivery Care (for births in the 5 years before the survey)',
#  'Delivery Care (for births in the 5 years before the survey)',
#  'Delivery Care (for births in the 5 years before the survey)',
#  'Delivery Care (for births in the 5 years before the survey)',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Child Vaccinations and Vitamin A Supplementation',
#  'Treatment of Childhood Diseases (children under age 5 years)',
#  'Treatment of Childhood Diseases (children under age 5 years)',
#  'Treatment of Childhood Diseases (children under age 5 years)',
#  'Treatment of Childhood Diseases (children under age 5 years)',
#  'Treatment of Childhood Diseases (children under age 5 years)',
#  'Treatment of Childhood Diseases (children under age 5 years)',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Child Feeding Practices and Nutritional Status of Children',
#  'Nutritional Status of Women (age 15-49 years)',
#  'Nutritional Status of Women (age 15-49 years)',
#  'Nutritional Status of Women (age 15-49 years)',
#  'Anaemia among Children and Women',
#  'Anaemia among Children and Women',
#  'Anaemia among Children and Women',
#  'Anaemia among Children and Women',
#  'Anaemia among Children and Women',
#  'Blood Sugar Level among Adults (age 15 years and above) Women',
#  'Blood Sugar Level among Adults (age 15 years and above) Women',
#  'Blood Sugar Level among Adults (age 15 years and above) Women',
#  'Blood Sugar Level among Adults (age 15 years and above) Men',
#  'Blood Sugar Level among Adults (age 15 years and above) Men',
#  'Blood Sugar Level among Adults (age 15 years and above) Men',
#  'Hypertension among Adults (age 15 years and above) Women',
#  'Hypertension among Adults (age 15 years and above) Women',
#  'Hypertension among Adults (age 15 years and above) Women',
#  'Hypertension among Adults (age 15 years and above) Men',
#  'Hypertension among Adults (age 15 years and above) Men',
#  'Hypertension among Adults (age 15 years and above) Men',
#  'Screening for Cancer among Women (age 30-49 years)',
#  'Screening for Cancer among Women (age 30-49 years)',
#  'Screening for Cancer among Women (age 30-49 years)',
#  'Tobacco Use and Alcohol Consumption among Adults (age 15 years and above)',
#  'Tobacco Use and Alcohol Consumption among Adults (age 15 years and above)',
#  'Tobacco Use and Alcohol Consumption among Adults (age 15 years and above)',
#  'Tobacco Use and Alcohol Consumption among Adults (age 15 years and above)',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
family = df[df['Category'] == 'Current Use of Family Planning Methods (currently married women age 15–49 years)']

# %%
family.head(12)
# Out:
#     Sl.No                                           Category  \
# 19   20.0  Current Use of Family Planning Methods (curren...
# 20   21.0  Current Use of Family Planning Methods (curren...
# 21   22.0  Current Use of Family Planning Methods (curren...
# 22   23.0  Current Use of Family Planning Methods (curren...
# 23   24.0  Current Use of Family Planning Methods (curren...
# 24   25.0  Current Use of Family Planning Methods (curren...
# 25   26.0  Current Use of Family Planning Methods (curren...
# 26   27.0  Current Use of Family Planning Methods (curren...
#
#             Indicators (2019-20) Urban Rural Total (2019-20) Total (2015-16)  \
# 19           20. Any method6 (%)    69  67.6            68.1            57.2
# 20    21. Any modern method6 (%)  66.9  66.5            66.7              57
# 21  22. Female sterilization (%)  61.3  62.2            61.9            54.2
# 22    23. Male sterilization (%)   1.4   2.3               2             1.6
# 23             24. IUD/PPIUD (%)     1   0.2             0.5             0.4
# 24                  25. Pill (%)   1.2   0.5             0.8             0.3
# 25                26. Condom (%)   1.3   0.5             0.8             0.5
# 26           27. Injectables (%)   0.1   0.1             0.1               0
#
#    Adilabad Bhadradri Hyderabad  ... Rajanna Sircilla Ranga Reddy Sangareddy  \
# 19     54.3        75      71.8  ...             60.7        72.6       62.3
# 20     54.1        74        70  ...             59.3        69.7       61.7
# 21     50.2      68.2      64.6  ...             49.9        67.6       56.8
# 22      0.6       2.2         0  ...              5.9         0.1        0.3
# 23        0       0.3       1.8  ...                0         0.3        0.6
# 24      1.2       0.9       1.9  ...              0.3         0.7          2
# 25      1.5       1.4       1.1  ...              1.8         0.7        1.1
# 26        0       0.3         0  ...              0.3         0.1        0.1
#
#    Siddipet Suryapet Vikarabad Wanaparthy, Warangal Rural Warangal Urban  \
# 19     59.8     78.2      69.8        77.3             60           67.7
# 20     59.4     77.9      69.8        75.7           57.5           64.4
# 21     54.5     75.9      68.7        74.4             47           50.1
# 22      0.9      0.4         0           0            8.7           11.2
# 23      0.7        0       0.3         0.2              0            0.4
# 24      1.3      0.4         0         0.3            0.8            0.7
# 25      1.3      0.3       0.4         0.3            0.3            1.2
# 26        0        0         0           0            0.3              0
#
#    Yadadri
# 19    76.2
# 20      75
# 21    72.3
# 22     0.2
# 23     0.3
# 24       0
# 25     0.7
# 26     0.2
#
# [8 rows x 38 columns]

# %%
family = family[['Indicators (2019-20)','Adilabad', 'Bhadradri',
       'Hyderabad', 'Jagitial', 'Jangoan', 'Jayashankar Bhupalapally',
       'Jogulamba Gadwal', 'Kamareddy', 'Karimnagar', 'Khammam',
       'KumurumBheem', 'Mahabubabad', 'Mahabubnagar', 'Mancherial', 'Medak',
       'Medchal-Malkajgiri', 'Nagarkurnool', 'Nalgonda', 'Nirmal', 'Nizamabad',
       'Peddapalli', 'Rajanna Sircilla', 'Ranga Reddy', 'Sangareddy',
       'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy,', 'Warangal Rural',
       'Warangal Urban', 'Yadadri']]

# %%
family = family.dropna()

# %%
family["avg_usage_in_state"] = family[['Adilabad', 'Bhadradri',
       'Hyderabad', 'Jagitial', 'Jangoan', 'Jayashankar Bhupalapally',
       'Jogulamba Gadwal', 'Kamareddy', 'Karimnagar', 'Khammam',
       'KumurumBheem', 'Mahabubabad', 'Mahabubnagar', 'Mancherial', 'Medak',
       'Medchal-Malkajgiri', 'Nagarkurnool', 'Nalgonda', 'Nirmal', 'Nizamabad',
       'Peddapalli', 'Rajanna Sircilla', 'Ranga Reddy', 'Sangareddy',
       'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy,', 'Warangal Rural',
       'Warangal Urban', 'Yadadri']].mean(axis=1)

# %%
family.head(12)
# Out:
#             Indicators (2019-20) Adilabad Bhadradri Hyderabad Jagitial  \
# 19           20. Any method6 (%)     54.3        75      71.8     57.4
# 20    21. Any modern method6 (%)     54.1        74        70     56.5
# 21  22. Female sterilization (%)     50.2      68.2      64.6     47.7
# 22    23. Male sterilization (%)      0.6       2.2         0      6.3
# 23             24. IUD/PPIUD (%)        0       0.3       1.8      0.8
# 24                  25. Pill (%)      1.2       0.9       1.9      0.7
# 25                26. Condom (%)      1.5       1.4       1.1      0.8
# 26           27. Injectables (%)        0       0.3         0        0
#
#    Jangoan Jayashankar Bhupalapally Jogulamba Gadwal Kamareddy Karimnagar  \
# 19      71                     64.8             75.5      56.8       56.8
# 20    70.4                     64.3             74.9      56.8       56.4
# 21    67.2                       51             71.5      55.9       44.4
# 22     1.4                     11.3                0       0.1       10.9
# 23     0.3                        0              0.5       0.3        0.1
# 24     0.3                      0.5              0.2       0.2        0.1
# 25     0.4                        1              0.1       0.3        0.6
# 26       0                      0.2                0         0          0
#
#     ... Ranga Reddy Sangareddy Siddipet Suryapet Vikarabad Wanaparthy,  \
# 19  ...        72.6       62.3     59.8     78.2      69.8        77.3
# 20  ...        69.7       61.7     59.4     77.9      69.8        75.7
# 21  ...        67.6       56.8     54.5     75.9      68.7        74.4
# 22  ...         0.1        0.3      0.9      0.4         0           0
# 23  ...         0.3        0.6      0.7        0       0.3         0.2
# 24  ...         0.7          2      1.3      0.4         0         0.3
# 25  ...         0.7        1.1      1.3      0.3       0.4         0.3
# 26  ...         0.1        0.1        0        0         0           0
#
#    Warangal Rural Warangal Urban Yadadri avg_usage_in_state
# 19             60           67.7    76.2          66.906452
# 20           57.5           64.4      75          65.648387
# 21             47           50.1    72.3          60.761290
# 22            8.7           11.2     0.2           2.290323
# 23              0            0.4     0.3           0.338710
# 24            0.8            0.7       0           0.632258
# 25            0.3            1.2     0.7           0.745161
# 26            0.3              0     0.2           0.116129
#
# [8 rows x 33 columns]

# %%
family_planning = family[['Indicators (2019-20)','avg_usage_in_state']]

# %%
family_planning.plot(x='Indicators (2019-20)', y=['avg_usage_in_state'], kind="bar")
# Out:
# <AxesSubplot:xlabel='Indicators (2019-20)'>
